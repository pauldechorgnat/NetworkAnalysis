# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
path = 'C:/Users/Marie/Desktop/MSc DSBA/3. Big Data Algorithms and Platforms/'

# %%
df_tweet = pd.read_csv(path + 'tweets.txt', names = ['tweet_id', 'tweet_user_id', 'tweet_creation_date', 'tweet_text'], skiprows=1)

# %%
df_tweet.head()
# Out:
#              tweet_id       tweet_user_id  tweet_creation_date  \
# 0  933477334627377152            71150481  2017-11-22 23:28:34
# 1  933477334371393542            88066231  2017-11-22 23:28:34
# 2  933477334790832128           156694080  2017-11-22 23:28:34
# 3  933477334681780224            18335624  2017-11-22 23:28:34
# 4  933477334274908160  720425908981489664  2017-11-22 23:28:34
#
#                                           tweet_text
# 0  RT @TheRickyDavila: Over the course of the ent...
# 1  RT @brianklaas: It's not the "Winter White Hou...
# 2  RT @Salon: Donald Trump lovers are attacking L...
# 3  RT @cbouzy: 🔥🔥BOMBSHELL!!! Trump’s disturbing ...
# 4              She's running https://t.co/GztNwg7oe8

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')

df_tweet['text_array'] = df_tweet['tweet_text'].apply(lambda x: tokenizer.tokenize(x.lower()))

# %%
stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
                 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers',
                 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves',
                 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are',
                 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does',
                 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until',
                 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into',
                 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down',
                 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here',
                 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',
                 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so',
                 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'rt']+\
['https', 'co', 'day', 'says', 'would', 'think', 'm', 'know', 'one', 'thank', 'doesn', 'get', 'time', 'amp', 'like', 're', 'could']

# %%
df_tweet['important'] = df_tweet['text_array'].apply(lambda x: [y for y in x if y not in stopwords])

# %%
frequencies ={}
for row in df_tweet['important']:
    for word in row:
        if word in frequencies.keys():
            frequencies[word] +=1
        else :
            frequencies[word] = 1
            
frequencies = pd.Series(frequencies).sort_values(ascending=False)

# %%
most_frequent = list(frequencies[:50].keys())
print(most_frequent)
# Out:
# ['trump', 'president', 'white', 'donald', 'clinton', 'people', 'man', 'thanksgiving', 'black', 'realdonaldtrump', 'obama', 'say', 'moore', 'hillary', 'pedophile', 'house', 'turkey', 'lavar', 'defend', 'us', 'condemn', 'sexual', 'ball', 'soho', 'goingglocal', 'dis', 'press', 'pardon', 'breaking', 'roy', 'judge', 'said', 'bill', 'hotel', 'america', 'joyannreid', 'new', 'supporters', 'let', '9th', 'told', 'via', 'circuit', 'overturns', 'nixon', 'anncoulter', 'johnson', 'news', 'kylegriffin1', 'thankful']

# %%
for col in most_frequent:
    df_tweet[col] = df_tweet['important'].apply(lambda x: col if col in x else '' )

# %%
df_tweet['most_important_array'] = df_tweet['important'].apply(lambda x: [y for y in x if y in most_frequent])

# %%
df_tweet['edges'] = df_tweet['most_important_array'].apply(lambda x: [(y,z) for y in x for z in x if y!=z])

# %%
df_tweet['edges'] = df_tweet['edges'].apply(lambda x: x[:int(len(x)/2)])

# %%
df_tweet.head()
# Out:
#              tweet_id       tweet_user_id  tweet_creation_date  \
# 0  933477334627377152            71150481  2017-11-22 23:28:34
# 1  933477334371393542            88066231  2017-11-22 23:28:34
# 2  933477334790832128           156694080  2017-11-22 23:28:34
# 3  933477334681780224            18335624  2017-11-22 23:28:34
# 4  933477334274908160  720425908981489664  2017-11-22 23:28:34
#
#                                           tweet_text  \
# 0  RT @TheRickyDavila: Over the course of the ent...
# 1  RT @brianklaas: It's not the "Winter White Hou...
# 2  RT @Salon: Donald Trump lovers are attacking L...
# 3  RT @cbouzy: 🔥🔥BOMBSHELL!!! Trump’s disturbing ...
# 4              She's running https://t.co/GztNwg7oe8
#
#                                           text_array  \
# 0  [rt, therickydavila, over, the, course, of, th...
# 1  [rt, brianklaas, it, s, not, the, winter, whit...
# 2  [rt, salon, donald, trump, lovers, are, attack...
# 3  [rt, cbouzy, bombshell, trump, s, disturbing, ...
# 4        [she, s, running, https, t, co, gztnwg7oe8]
#
#                                            important  trump president  white  \
# 0  [therickydavila, course, entire, 2016, electio...  trump
# 1  [brianklaas, winter, white, house, visit, cost...                   white
# 2  [salon, donald, trump, lovers, attacking, leva...  trump
# 3  [cbouzy, bombshell, trump, disturbing, choice,...  trump
# 4                              [running, gztnwg7oe8]
#
#    donald ... fbi even thehill administration away support since widow start h
# 0         ...
# 1         ...
# 2  donald ...
# 3         ...
# 4         ...
#
# [5 rows x 88 columns]

# %%
tweet_graph = nx.graph.Graph()

# %%
for word in most_frequent:
    tweet_graph.add_node(word)

# %%
edge_frequencies = {}
for row in df_tweet['edges']:
    for edge in row:
        if edge in edge_frequencies.keys():
            edge_frequencies[edge]+=1
        else :
            edge_frequencies[edge]=1

weighted_edges = []
maximum_edge_freq = max(edge_frequencies.values())
for edge in edge_frequencies.keys():
    x,y = edge
    weighted_edges.append((x, y, edge_frequencies[edge]/maximum_edge_freq))

# %%
for edge in edge_frequencies:
    tweet_graph.add_weighted_edges_from(weighted_edges)

# %%
pos=nx.circular_layout(tweet_graph)

# %%
plt.figure(figsize=(16,16))
nx.draw_networkx_nodes(tweet_graph, pos, node_color = 'black')
nx.draw_networkx_edges(tweet_graph, pos, alpha = .7, edge_color = 'grey')
nx.draw_networkx_labels(tweet_graph, pos, font_color  = 'red', font_size = 16)
plt.savefig(path + 'trump_tweets.png')
plt.show()

# %%
weight_edges_tuples_sup ={str(weight):[(u,v) for (u,v,w) in weighted_edges if w>weight-.01 and w<=weight] for weight in np.array(range(1,101))/100}
weight_edges_tuples_inf ={str(weight):[(u,v) for (u,v,w) in weighted_edges if w>weight and w<=weight+.01] for weight in np.array(range(0,100))/100}

# %%
plt.figure(figsize=(16,16))
nx.draw_networkx_nodes(tweet_graph, pos, node_color = 'black', node_size = 10)
for key in weight_edges_tuples_inf.keys():
    nx.draw_networkx_edges(tweet_graph, pos, edgelist=weight_edges_tuples_inf[key], alpha = float(key), edge_color = 'k')
nx.draw_networkx_labels(tweet_graph, pos, font_color  = 'red', font_size = 16)
plt.savefig(path + 'trump_tweets_circular.png')
plt.show()

# %%
df_tweet.shape
# Out:
# (565844, 88)
